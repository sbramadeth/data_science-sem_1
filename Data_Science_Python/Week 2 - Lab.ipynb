# %% [markdown]
# <div>
#     <h4>Question 1</h4>
#     <p>Write a program that will output the text “Hello There” to screen. Create a String
# variable to store your name and an int variable to store your age. Print this out to
# screen.</p>
# </div>

# %%
file = open ("file_name", "r")
car_data = []

for file in line:
    line = line.strip()
    value = line.split(",")
    car_data.append(value)
file.close
print(car_data)
# Out:
# Hello there
# the age is 25

# %% [markdown]
# <div>
#     <h4>Question 2</h4>
#     <p>Write a program that asks the user to enter a distance in kilometres and then convert
# that distance to miles (Miles = Kilometres * 0.6214).</p>
# </div>

# %% [markdown]
# <div>
#     <h4>Question 3</h4>
#     <p>Write a program that will ask a student for their first name and then for their surname
# and their grades for Biology, Chemistry and Math. The program should then print out
# the full name of the student along with their average numerical grade (Use only a
# single print statement)</p>
# </div>

# %%
<div>
    <h4>Question 1</h4>
    <p></p>
</div>

# %% [markdown]
# <div>
#     <h4>Question 4</h4>
#     <p>4.	Write a program to calculate and display a person’s body mass index (BMI). A persons BMI is calculated with the following formula:
# </p>
# <ul><li>BMI = (weight/ height<sup>2</sup>)</li></ul
# </div>

# %%
def calculate_bmi(weight_kg, height_m):
  """Calculates BMI given weight in kilograms and height in meters."""
  if height_m <= 0:
    return None  # Cannot calculate BMI if height is zero or less

# %% [markdown]
# <div>
#     <h4>Question 5</h4>
#     <p>There are three seating categories at a stadium. For a football games, Class A seat’s cost €25, Class B seat’s cost €20 and Class C seat’s cost €15. Write a program that asks how many tickets for each class of seats were sold, and then display the amount of income generated from ticket sales.</p>
# </div>

# %% [markdown]
# <div>
#     <h4>Question 6</h4>
#     <p>	Write a program to calculate the area of a triangle with a given Height and Base. The Height and Base should be provided by the user. The formulae is A = (h*b)/2.</p>
# </div>

# %% [markdown]
# <div>
#     <h4>Question 7</h4>
#     <p>Write a program to calculate the volume of a sphere given a radius provided by the user. The formulae is V = (4/3)*Pi*r3. What would be the volume of the Moon considering a radius of 1,737.5km and Pi as 3.1415. Now, calculate the mass of the moon by using the formulae mass = Density * Volume, where the moon’s density is defined as 1410kg/m3.</p>
# </div>

# %% [markdown]
# <div>
#     <h4>Question 8</h4>
#     <p>	Now that we know the Moon’s mass, how many nuclear bombs worth of Kinect energy a direct impact between the Moon and the Earth would generate? Consider the Earth’s speed as 0 and the Moon’s as 3683 km/h. The formulae for this crazy scenario is KE = (mxv<sup>2</sup>)/2. V is velocity and it needs to be transformed to m/s. For reference, the Hiroshima bomb generated a total of 63,000,000,000 KJ of energy!</p>
# </div>
