# %% [markdown]
# <h4>Question 1</h4>
# <p>You are given a list of tuples, where each tuple contains an animal's name and their estimated top-speed in km/h:</p>
# <p>Using <strong>List comprehension</strong>, create a new list of strings that:</p>
# <ol>
#     <li>Includes only animals with a top-speed higher than 60km/h</li>
#     <li>Formats the string as "Animal: &lt;name&gt;, Speed: &lt;speed&gt; where &lt;name&gt; and &lt;speed&gt; are dinamically replaced by the animal's name and speed"</li>
#     <li>Convert the animal's name to uppercase if their speed is <strong style="color:red;">90</strong> or above.</li>
# </ol>

# %%
animals_speed = [
    ('Cheetah', 120), ('Peregrine Falcon', 389), ('Pronghorn Antelope', 98), 
    ('Springbok', 88), ('Lion', 80), ('Blackbuck', 80), ('Hare', 80), 
    ('Greyhound', 72), ('Horse', 88), ('Blue Wildebeest', 80), ('Thomson’s Gazelle', 80), 
    ('Quarter Horse', 88), ('Ostrich', 70), ('African Wild Dog', 64), ('Kangaroo', 71), 
    ('Jackrabbit', 72), ('Mongolian Wild Ass', 65), ('Caracal', 80), ('Brown Hare', 77), 
    ('Elephant', 40), ('Giraffe', 60), ('Cape Hunting Dog', 56), ('Grizzly Bear', 56), 
    ('Zebra', 65), ('Wolf', 65), ('Hyena', 60), ('Rabbit', 56), ('Polar Bear', 40), 
    ('Elk', 72), ('Reindeer', 80), ('American Bison', 56), ('Coyote', 69), 
    ('Wild Boar', 48), ('Moose', 56), ('Domestic Cat', 48), ('Jaguar', 80), 
    ('Tiger', 65), ('Leopard', 58), ('Hyrax', 24), ('Rhinoceros', 55), 
    ('Squirrel', 19), ('Fox', 50), ('Maned Wolf', 48), ('Fallow Deer', 48), 
    ('Ibex', 50), ('Warthog', 48), ('Badger', 30), ('Lynx', 50), ('Beagle', 32), 
    ('Collie', 48), ('Cheetah Cub', 48), ('Puma', 80), ('Spotted Hyena', 60), 
    ('Eagle', 160), ('Hawk', 120), ('Turkey Vulture', 80), ('Swallow', 83), 
    ('Frigatebird', 153), ('Golden Eagle', 320), ('Albatross', 115), 
    ('Marlin', 132), ('Swordfish', 97), ('Sailfish', 110), ('Killer Whale', 56), 
    ('Dolphin', 60), ('Tuna', 75), ('Bonito', 64), ('Great White Shark', 56), 
    ('Mako Shark', 74), ('Yellowfin Tuna', 76), ('Blue Shark', 69), ('Leatherback Turtle', 35), 
    ('Flying Fish', 56), ('Penguin', 36), ('Bald Eagle', 120), ('Red Fox', 50), 
    ('Sea Lion', 40), ('Otter', 12), ('Puma', 80), ('Ocelot', 60), ('Cougar', 64), 
    ('Snow Leopard', 64), ('Serval', 80), ('Caribou', 80), ('Llama', 56), 
    ('Mule', 40), ('Bison', 56), ('Goat', 16), ('Sheep', 25), ('Donkey', 24), 
    ('Alpaca', 56), ('Camel', 65), ('Yak', 40), ('Chamois', 50), ('Impala', 90), 
    ('Komodo Dragon', 20), ('Monitor Lizard', 32), ('Wild Turkey', 32), ('Chicken', 14), 
    ('Dog', 72), ('Cat', 48)
]

# %% [markdown]
# <h4>Bonus:</h4>
#
# <p>Modify your list comprehension so that animals with a speed between 60 and 70 (inclusive) have their names converted to lowercase.</p>

# %% [markdown]
# <h4>Question 2:</h4>
#
# <p>Let's reuse the previous list of animals, but this time you will use dictionary comprehension to create a dictionary, where:</p>
#
# <ol>
#     <li>The <strong>keys</strong> are the animal names.</li>
#     <li>The <strong>values</strong> are the categories based on their speed
#         <ul>
#             <li>&quot;Fast&quot; if the speed is 70km/h or more</li>
#             <li>&quot;Moderate&quot; if the speed is between 40 and 69 km/h</li>
#             <li>&quot;slow&quot; if the speed is less than 40km/h</li>
#         </ul>
#     </li>
# </ol>

# %% [markdown]
# <h4>Bonus:</h4>
#
# <p>Modify your dictionary comprehension to include the speed next to the category as a tuple, for example:</p>
#
# <pre>{
#         <span style="color:green;">"Cheetah"</span>:(<span style="color:green;">"Fast"</span>, <span style="color:gold;">120</span>)
#         <span style="color:green;">"Peregrine Falcon"</span>:(<span style="color:green;">"Fast"</span>, <span style="color:gold;">389</span>)
# }
# </pre>

# %% [markdown]
# <h4>Question 3</h4>
#
# <p>Write a calculator program using functions. The program should first ask the user for two separate numerical values. It should then give the user an option to perform one of four operations:  addition, subtraction, division or multiplication. Therefore, if the user selects multiplication then your program should print out the product of the two values.  You should write a different function for performing each operation. For example the sum function will take in two numerical parameters and return the result.</p>

# %% [markdown]
# <h4>Question 4</h4>
#
# <p>Write a function called printReverseNumTriangle, that accepts a number as its argument and prints a triangle of the size specified by number so that each row in the triangle is made up of the row number displayed.</p>

# %% [markdown]
# <h4>Question 5</h4>
#
# <p>Write a simple guessing game for a user. This program should initially generate a random number between 1 and 100.
#
# It should then repeatedly ask the user to guess the random number.
#
# Each time the user enters a guess the program should tell them that their guess was too high, too low or correct.
#
# When the user finally guesses the correct number the program should tell the user how many guesses they made before arriving at the correct number.</p>
#
# <p>Your program should make use of the following methods:</p>
# <ol>
#     <li>generateRandomNumber. This function will generate a random number between 0-100 and return the result.</li>
#     <li>askUser. This function will ask the user to enter a guess and will return the result</li>
#     <li>checkGuess. This function will take in the users guess and the random number as parameters and will return True if the user entered the correct value and False otherwise. </li>
# </ol>

# %% [markdown]
# <h4>Question 6</h4>
#
# <p>Sort the list containing the animal's names first by using the speed and them their names</p>

# %% [markdown]
# <h4>Question 7</h4>
#
# <p>Create a Haikai (Yes, you can use chatGPT for this one), and save it into a file. When opening the file you need to use the appending mode (<strong>a</strong>).</p>
# <p>Now create a second Haikai and save it on the same file, what happened?</p>
