# %% [markdown]
# ### Question 1
#
# Ask the user to enter two numbers from the command line. Your program should output the value of the larger number. You can assume that the user will enter different values for number 1 and 2.

# %% [markdown]
# ### Question 2
#
# The area of a rectangle is the length multiplied by width. Write a program that asks for the length and width of two rectangles. The program should tell the user which rectangle has the greater area or if the areas are the same.

# %% [markdown]
# ### Question 3
# A development company will only employ an individual if they have a minimum of 4 years of commercial software development experience, a Microsoft certification and a first class honours undergraduate computing degree.
#
# ### (i)
# Write a program that will use nested if statements to determine if a user is sufficiently qualified to be employed. The first if statement should check if the user has 4 years of commercial software development experience, the second nested if statement should check if they have a Microsoft certification and the final nested if statement should check if the user has a first class honours undergraduate computing degree.
# If the user does not satisfy one of the conditions the program should inform the user that they not eligible and should also inform the user of the requirement they have failed. The program should then exit.

# %% [markdown]
# ### (ii)
#
# Rewrite the above program so you only use only a single if statement to check that the user satisfies the above conditions to be employed (you will need to use an and logical operator). Please note this version of the program will ask the user to enter all relevant information first and will then inform the user if they are eligible or not. Note it doesn’t need to inform the user of the specific reasons as to why they were not accepted.

# %% [markdown]
# ### Question 4
#
# Write a program that will ask the user to enter the number of packages purchased. The program should display the amount of the discount (if any) and the total amount of the purchase after the discount.
# Please use if / elif statements to solve this problem and note that your solution to this problem should make use of the and logical operator where possible. Details are as follow:
#
# <ul>
#     <li>50% of discount if the user buys more than 100 packages.</li>
#     <li>40% of discount if the user buys up to 100 packages.</li>
#     <li>30% if the user buys between 80 and 99.</li>
#     <li>20% for 70-89.</li>
#     <li>10% for 50-69.</li>
#     <li>0 otherwise.</li>
# </ul>
# <p>The package cost is 20 euros and y</p>

# %% [markdown]
# ### Question 5
#
# Write a program that will ask the user to enter three numerical float values. Using conditional statements your program should print out the largest of the three numbers.

# %% [markdown]
# <div>
#     <h4>Question 6</h4>
#     <p>Write a program and ask the user to enter two numerical values. Create then a calculator to do the following:</p>
#     <ul>
#         <li>Sum</li>
#         <li>Difference</li>
#         <li>Multiplication</li>
#         <li>Division</li>
#         <li>Module</li>
#         <li>Power</li>
#     </ul>
#     <p>Use only match-case structure for this exercise</p>
# </div>

# %% [markdown]
# <div>
#     <h4>Question 7</h4>
#     <p>Create a program to test if a triangle built with 3 sides provided by the user is a valid triangle or not. A triangle is only valid when the sum of 2 of its sides is greater than the third.</p>
# </div>
