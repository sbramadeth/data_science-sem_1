# %% [markdown]
# <h4>Question 1</h4>

# %% [markdown]
# <p><strong>Task 1 - </strong>Write a loop that counts from 0 to 20 (inclusive) using a while loop. Do the same loop but use a for loop and the range() built-in function.</p>

# %% [markdown]
# <p><strong>Task 2 - </strong>Write a program that will ask the user to enter an integer value greater than 0. If a user enters a negative value the program should continue to ask the user to enter a positive value (use a while loop to achieve this). Once the user has entered a positive value the program should print out all numbers between 0 and the positive value (use a for loop for this)</p>

# %% [markdown]
# <p><strong>Task 3 - </strong>Write a program that will print out the ten times tables. (10*0, 10*1, ..., 10*12). (Use a for loop when implementing this functionality).</p>
#
# <p>Example:</p>
# <ul style = "list-style-type: none;">
#     <li>1 * 0 = 0</li>
#     <li>1 * 1 = 1</li>
#     <li>1 * 2 = 2</li>
#     <li>1 * 3 = 3</li>
#     <li>...</li>
# </ul>

# %% [markdown]
# <p><strong>Task 4 - </strong>Your objective in this question is to write a more flexible version of the program you wrote the times table question. You should ask the user for two values. The first value, num, is the number that we will multiply by 0, 1, 2, 3, etc. The second number, limit, is the number at which we will stop multiplying.</p>

# %% [markdown]
# <h4>Question 2</h4>
# <p><strong>Task 1 - </strong>Write code to output the pattern of stars below (6 rows of 5 stars`each).</p>
#
# <p>Example:</p>
# <ul style = "list-style-type: none;">
#     <li>*****</li>
#     <li>*****</li>
#     <li>*****</li>
#     <li>*****</li>
#     <li>*****</li>
#     <li>*****</li>
# </ul>

# %% [markdown]
# <p><strong>Task 2 - </strong>Write a program that will ask a user for how many stars to display on a single line and also how many lines of stars to display. The program should then output the resulting sequence of stars.</p>

# %% [markdown]
# <h4>Question 3 </h4>
# <p>Write a loop that prompts the user to enter a series of pizza toppings until they enter a 'quit' value. As they enter each topping, print a message saying you’ll add that topping to their pizza.</p>

# %% [markdown]
# <h4>Question 4 </h4>
#
# <p>A movie theater charges different ticket prices depending on a person’s age. If a person is under the age of 3, the ticket is free; if they are between 3 and 12, the ticket is 10 euros; and if they are over age 12, the ticket is 15. Write a loop in which you ask users their age, and then tell them the cost of their movie ticket.</p>
